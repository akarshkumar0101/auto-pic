# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %run imports_notebook.py

# %%
from PIL import Image
from torchvision import transforms

# %%
malik = Image.open('imgs/dog.png')
malik
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=1395x924>

# %%
trans = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224, 224)),
])

# %%
img = plt.imread('imgs/dog.png')[:, :, :3]
img = trans(img)

# %%
from image_cppn import ImageCPPN

# %%
cppn = ImageCPPN(n_hidden=100, n_layers=20, n_channels=3, activation=torch.relu, give_radius=True)
cppn = cppn.to(device)

img = plt.imread('imgs/waterfall.jpg')[:, :, :3]
img = trans(img)

opt = torch.optim.Adam(cppn.parameters(), lr=1e-2)

y = img.to(device)
print(y.shape)

for i in range(100000):
    img = cppn.generate_image((224, 224))
    
    loss = (img-y).pow(2.).mean()
    
    opt.zero_grad()
    loss.backward()
    opt.step()
    
    if i%400==0:
        print(loss.item())
        plt.imshow(to_np(img[0].permute(1, 2, 0)))
        plt.show()
# Out:
# torch.Size([3, 224, 224])
# 0.07595859467983246
# 0.01739189773797989
# 0.014228143729269505
# 0.012536955997347832
# 0.011550151742994785
# 0.011149565689265728
# 0.011210057884454727
# 0.010919402353465557
# 0.010911156423389912
# 0.010367906652390957
# 0.010478713549673557
# 0.00997254904359579
# 0.010213598608970642
# 0.009427037090063095
# 0.00991552323102951
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/akarshkumar0101/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2744/1245481426.py", line 13, in <cell line: 12>
#     img = cppn.generate_image((224, 224))
#   File "/home/akarshkumar0101/auto-pic/image_cppn.py", line 78, in generate_image
#     x = x.to(self.layers[0].weight.device)
# KeyboardInterrupt
#
# ...

# %%
a = cppn.generate_image((224*5, 224*5))
plt.figure(figsize=(20, 20))
plt.imshow(to_np(a[0].permute(1, 2, 0)))
